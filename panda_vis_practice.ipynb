# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
dates = pd.date_range('1/1/2000', periods = 500)

# %%
col_D = np.random.rand(500)

# %%
data1 = np.random.randn(500, 3)

# %%
df1 = pd.DataFrame(data = data1, index = dates, columns = ['A','B','C'])

# %%
df1.head()
# Out:
#                    A         B         C
# 2000-01-01  1.360089  0.864038 -0.958194
# 2000-01-02  0.119191 -0.311145  0.460874
# 2000-01-03  0.066545 -0.505514  1.017540
# 2000-01-04  0.602241 -0.352045  0.179990
# 2000-01-05  0.791831  1.598972  1.299882

# %%
df1['D'] = col_D

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.360089  0.864038 -0.958194  0.942505
# 2000-01-02  0.119191 -0.311145  0.460874  0.561760
# 2000-01-03  0.066545 -0.505514  1.017540  0.664035
# 2000-01-04  0.602241 -0.352045  0.179990  0.632507
# 2000-01-05  0.791831  1.598972  1.299882  0.460564

# %%
data2 = np.random.rand(20,3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data = data2, columns = col)

# %%
df2.head()
# Out:
#           X         Y         Z
# 0  0.294544  0.447076  0.866110
# 1  0.032919  0.041472  0.023011
# 2  0.986392  0.798202  0.987440
# 3  0.535551  0.104014  0.835749
# 4  0.679494  0.953034  0.013641

# %%
df1['A'].hist(bins = 50)

# %%
df1['A'].plot(kind = 'hist', bins = 50)

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins = 50)

# %%
plt.style.use('bmh')
df1['A'].hist(bins = 50)

# %%
plt.style.use('dark_background')
df1['A'].hist(bins = 50)

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist(bins = 50)

# %%
plt.style.use('ggplot')

# %%
df2.plot(kind = 'area', alpha = 0.5)

# %%
df2.plot.area(alpha = 0.5)

# %%
df2.plot.bar()

# %%
df2.plot.barh()

# %%
df2.plot.bar(stacked = True)

# %%
df1.plot.hist(bins = 30, alpha = 0.5)

# %%
df1.plot.hist(stacked = True)

# %%
df1.plot.hist(orientation = 'horizontal', alpha = 0.5)

# %%
#df1.plot.line(x = df1.index, y = 'A', lw=1, figsize(12,10))

# %%
df1.plot.scatter(x='A', y='B')

# %%
ax = df1.plot.scatter(x='A', y='B', color = 'DarkBlue', label = 'Group1')
df1.plot.scatter(x='C', y='D', color = 'DarkGreen', ax=ax, label = 'Group2')

# %%
df1.plot.scatter(x='A', y='B', c = 'C', s = 50, cmap = 'coolwarm')

# %%
df1.plot.scatter(x='A', y='B', s = df1['C']*100)
# Out:
# /Users/Vsevolod/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df2.plot.box(vert = False)

# %%
color = dict(boxes = 'DarkGreen', whiskers = 'DarkOrange',
            medians = 'DarkBlue', caps = 'Grey')

# %%
df2.plot.box(color = color)

# %%
df2['group'] = np.random.choice(['A', 'B'], size = 20)
df2
# Out:
#            X         Y         Z group
# 0   0.294544  0.447076  0.866110     A
# 1   0.032919  0.041472  0.023011     A
# 2   0.986392  0.798202  0.987440     B
# 3   0.535551  0.104014  0.835749     A
# 4   0.679494  0.953034  0.013641     B
# 5   0.890039  0.619808  0.989272     A
# 6   0.750508  0.765484  0.785363     A
# 7   0.348391  0.056610  0.425616     A
# 8   0.102912  0.190168  0.869259     B
# 9   0.863851  0.183580  0.023585     A
# 10  0.674178  0.237750  0.042576     A
# 11  0.126118  0.726036  0.902249     B
# 12  0.594117  0.620727  0.171995     A
# 13  0.384445  0.034372  0.188010     A
# 14  0.879250  0.126243  0.686950     A
# 15  0.983370  0.207562  0.282343     A
# 16  0.046688  0.954532  0.759692     A
# 17  0.341533  0.582214  0.792481     B
# 18  0.142539  0.393429  0.604367     A
# 19  0.200866  0.142944  0.782714     B

# %%
df2.boxplot(column = ['X', 'Y'], by = 'group')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12412e470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1241616a0>],
#       dtype=object)

# %%
df2.drop('group', axis = 1, inplace = True)
df2.head()
# Out:
#           X         Y         Z
# 0  0.294544  0.447076  0.866110
# 1  0.032919  0.041472  0.023011
# 2  0.986392  0.798202  0.987440
# 3  0.535551  0.104014  0.835749
# 4  0.679494  0.953034  0.013641

# %%
df1.plot.hexbin(x='A', y='B', gridsize = 25, cmap = 'Oranges')

# %%
df2['X'].plot.kde() #we can use density instead of kde

# %%
df2.plot.density()

# %%
df2.plot.pie(y = 'X', figsize = (4,4), legend = False)

# %%
df2.plot.pie(subplots = True, figsize = (12,4), legend = False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a2a67a0b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2a794e10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a2a7306a0>],
#       dtype=object)
